# %%
import matplotlib.pyplot as plt

# %%
area = [500, 700, 900, 1100, 1300, 1500, 1700, 1900, 2100, 2300]

# %%
price = [15, 20, 28, 35, 40, 50, 55, 62, 70, 75]

# %%
plt.scatter(price , area)
plt.title("Relation between area and house price")
plt.show()
